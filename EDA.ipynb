# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('melb_data.csv')

# %%
## First five rows
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
## Last five rows
data.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
## First 10 rows
data.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford    40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford         55a Park St      4    h  1600000.0     VB  Nelson
# 5  Abbotsford      129 Charles St      2    h   941000.0      S  Jellis
# 6  Abbotsford        124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford       98 Charles St      2    h  1636000.0      S  Nelson
# 8  Abbotsford  6/241 Nicholson St      1    u   300000.0      S  Biggin
# 9  Abbotsford       10 Valiant St      2    h  1097000.0      S  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# ...

# %%
## Last 10 rows
data.tail(10)
# Out:
#                Suburb        Address  Rooms Type      Price Method  \
# 13570  Wantirna South  34 Fewster Dr      3    h   970000.0      S
# 13571  Wantirna South     15 Mara Cl      4    h  1330000.0      S
# 13572        Watsonia  76 Kenmare St      2    h   650000.0     PI
# 13573        Werribee    5 Nuragi Ct      4    h   635000.0      S
# 13574     Westmeadows     9 Black St      3    h   582000.0      S
# 13575   Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576    Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577    Williamstown    83 Power St      3    h  1170000.0      S
# 13578    Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579      Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 13570          Barry  26/08/2017      14.7    3152.0  ...       2.0  2.0
# 13571          Barry  26/08/2017      14.7    3152.0  ...       2.0  2.0
# ...

# %%
## Statistical information
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# Price has a range of values between 85000 to 900000. If we observe the mean value and the standard deviation we understand that data is distributed unevenly.

# %%
## Total null values in each column
data.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
## Column values
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
## Individual column categories
data['Rooms'].unique()
# Out:
# array([ 2,  3,  4,  1,  6,  5,  8,  7, 10], dtype=int64)

# %%
## Number of unique values
data.nunique()
# Out:
# Suburb             314
# Address          13378
# Rooms                9
# Type                 3
# Price             2204
# Method               5
# SellerG            268
# Date                58
# Distance           202
# Postcode           198
# Bedroom2            12
# Bathroom             9
# Car                 11
# Landsize          1448
# BuildingArea       602
# YearBuilt          144
# CouncilArea         33
# Lattitude         6503
# Longtitude        7063
# Regionname           8
# Propertycount      311
# dtype: int64

# %%
## correlation coefficient
data.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %%
## Duplicates
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Length: 13580, dtype: bool

# %% [markdown]
# ## Visualizations

# %%
## Scatter Plot
plt.scatter(data['Distance'],data['Price'])

# %%
## Histogram
plt.hist(data['Price'],bins=15)
# Out:
# (array([3.803e+03, 5.938e+03, 2.524e+03, 8.100e+02, 3.020e+02, 1.100e+02,
#         5.100e+01, 1.900e+01, 9.000e+00, 8.000e+00, 3.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00]),
#  array([  85000.        ,  679333.33333333, 1273666.66666667,
#         1868000.        , 2462333.33333333, 3056666.66666667,
#         3651000.        , 4245333.33333333, 4839666.66666667,
#         5434000.        , 6028333.33333333, 6622666.66666667,
#         7217000.        , 7811333.33333333, 8405666.66666667,
#         9000000.        ]),
#  <a list of 15 Patch objects>)

# %%
## Boxplot
plt.boxplot(data['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x201acc96af0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x201acca31f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x201acc96790>],
#  'medians': [<matplotlib.lines.Line2D at 0x201acca38b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x201acca3bb0>],
#  'means': []}
